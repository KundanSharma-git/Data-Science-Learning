# %% [markdown]
# <a href="https://colab.research.google.com/github/KundanSharma-git/Data-Science-Learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("titanic.csv")

# %%
dataset.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #Mean

# %%
dataset["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
np.mean(dataset["Age"])
# Out:
# np.float64(29.69911764705882)

# %%
sns.histplot(x = "Age",data = dataset)
plt.show()

# %% [markdown]
# **Median**

# %%
np.median(dataset["Age"])
# Out:
# np.float64(nan)

# %%
np.median(dataset["Fare"])
# Out:
# np.float64(14.4542)

# %% [markdown]
# **Mode**

# %%
dataset["Fare"].mode()
# Out:
# 0    8.05
# Name: Fare, dtype: float64

# %%
dataset["Fare"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64>

# %% [markdown]
# #Range

# %%
min_r = dataset["Age"].min()
max_r = dataset["Age"].max()

# %%
min_r,max_r
# Out:
# (0.42, 80.0)

# %%
range = max_r - min_r

# %%
range
# Out:
# 79.58

# %% [markdown]
# #Mean Absolute Deviation

# %%
sec_a =np.array([75,65,73,68,72,76])
sec_b = np.array([90,47,43,96,93,51])

# %%
mean = np.mean(sec_b)
mean
# Out:
# np.float64(70.0)

# %%
mad_a = np.sum(np.abs(sec_a-mean))/len(sec_a)
mad_b = np.sum(np.abs(sec_b-mean))/len(sec_b)

# %%
mad_a,mad_b
# Out:
# (np.float64(3.8333333333333335), np.float64(23.0))

# %% [markdown]
# Standard Deviation

# %%
np.std(sec_a) , np.std(sec_b)
# Out:
# (np.float64(3.8622100754188224), np.float64(23.18045153428495))

# %% [markdown]
# #Variance

# %%
np.var(sec_a) , np.var(sec_b)
# Out:
# (np.float64(14.916666666666666), np.float64(537.3333333333334))

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
